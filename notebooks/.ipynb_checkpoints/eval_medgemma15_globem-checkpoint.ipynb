# %% [markdown]
# # Baseline Evaluation — medgemma15
#
# Text-only zero-shot evaluation on the GLOBEM HRS dataset.
# Predicts Harbor Risk Score (0, -1, -2, -3) from serialized behavioral prompts.
#
# **Requirements:** `transformers`, `accelerate`, `huggingface_hub`, `pandas`
# **GPU:** Recommended (A10G / T4 or better). Falls back to CPU but will be slow.

# %%
import json
import sys
from datetime import datetime
from pathlib import Path

import pandas as pd
from huggingface_hub import login
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch

# ── Add notebooks/ dir to path so eval_utils is importable ───────────────────
sys.path.insert(0, str(Path.cwd()))
from eval_utils_bdi import slugify, normalize_text, extract_bdi_prediction, compute_metrics
import warnings
import transformers
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()
ROOT        = Path.cwd().parent
CONFIG_PATH = ROOT / "config" / "eval_config.json"
MODEL_KEY   = "medgemma15"

with CONFIG_PATH.open("r", encoding="utf-8") as f:
    config = json.load(f)

model_name        = config["models"][MODEL_KEY]
system_prompt_text = config["system_prompt_text"]
system_prompt_id  = slugify(system_prompt_text)
model_slug        = slugify(MODEL_KEY)

print(f"Model key   : {MODEL_KEY}")
print(f"Model name  : {model_name}")
print(f"Prompt id   : {system_prompt_id}")
print(f"Device      : {'cuda' if torch.cuda.is_available() else 'cpu'}")
# Out:
# Model key   : medgemma15
# Model name  : google/medgemma-4b-it
# Prompt id   : you_are_a_clinical_decision_support_assistant_specializing_in_be
# Device      : cuda

# %% [markdown]
# ## 1. Authenticate and load model

# %%
# Gemma / MedGemma models require a Hugging Face account with accepted licence.
# Run `login()` once; it caches your token in ~/.cache/huggingface/.
from huggingface_hub import login
import os
login(token=os.environ["HF_TOKEN"])

dtype = torch.bfloat16 if torch.cuda.is_available() else torch.float32

pipe = pipeline(
    "text-generation",          # text-only; no image column used
    model=model_name,
    torch_dtype=dtype,
    device_map="auto",          # uses GPU if available, else CPU
)
print(f"Pipeline ready: {pipe.model.__class__.__name__}")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Loading weights: 100%|████████████████████████| 883/883 [01:04<00:00, 13.69it/s]
# Pipeline ready: Gemma3ForConditionalGeneration

# %% [markdown]
# ## 2. Load dataset

# %%
data_csv = ROOT / config["data_csv"]
df = pd.read_csv(data_csv)

# Validate required columns exist (image_path_or_url is present but unused)
required_cols = set(config["required_columns"])
missing = required_cols - set(df.columns)
if missing:
    raise ValueError(f"Missing required columns: {sorted(missing)}")

# gold_answer must be one of 0/-1/-2/-3
# It's set for BDI now
valid_labels = {"Minimal", "Mild", "Moderate", "Severe"}
bad_labels = df[~df["gold_answer"].astype(str).isin(valid_labels)]
if len(bad_labels):
    raise ValueError(f"{len(bad_labels)} rows have unexpected gold_answer values.")

print(f"Loaded {len(df):,} rows from {data_csv.name}")
print(f"Label distribution:\n{df['gold_answer'].value_counts().sort_index()}")
# Out:
# Loaded 505 rows from globem_bdi_eval.csv
# Label distribution:
# gold_answer
# Mild         94
# Minimal     307
# Moderate     77
# Severe       27
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Run inference

# %%
results   = []
run_ts    = datetime.now().strftime("%Y%m%d_%H%M%S")
gen_cfg   = config.get("generation", {"max_new_tokens": 10, "do_sample": False})

for _, row in df.iterrows():
    sample_id   = row["sample_id"]
    question    = str(row["question"])
    gold_answer = str(row["gold_answer"]).strip()

    # Build a chat-style message list (no image content)
    messages = [
        {"role": "system",  "content": system_prompt_text},
        {"role": "user",    "content": question},
    ]

    output_obj = pipe(messages, **gen_cfg)
    # change to hrs if you want hrs prediction extraction   
    pred_text  = extract_bdi_prediction(output_obj)

    results.append({
        "sample_id":        sample_id,
        "model_name":       model_name,
        "system_prompt_id": system_prompt_id,
        "system_prompt_text": system_prompt_text,
        "question":         question,
        "gold_answer":      gold_answer,
        "prediction_raw":   json.dumps(output_obj, ensure_ascii=False),
        "prediction_text":  pred_text,
        "exact_match":      int(pred_text == gold_answer),
        "normalized_match": int(normalize_text(pred_text) == normalize_text(gold_answer)),
        "timestamp":        datetime.now().isoformat(),
    })
    if len(results) % 50 == 0:
            print(f"{len(results)}/{len(df)} done", flush=True)

results_df = pd.DataFrame(results)
print(f"Inference complete. Parsed predictions: "
      f"{results_df['prediction_text'].ne('').sum():,} / {len(results_df):,}")
results_df[["sample_id","gold_answer","prediction_text","exact_match"]].head(5)
# Out:
# 50/505 done
# 100/505 done
# 150/505 done
# 200/505 done
# 250/505 done
# 300/505 done
# 350/505 done
# 400/505 done
# 450/505 done
# 500/505 done
# Inference complete. Parsed predictions: 505 / 505
#             sample_id gold_answer prediction_text  exact_match
# 0  INS-W_1000_2021_13     Minimal        Moderate            0
# 1  INS-W_1002_2021_13    Moderate        Moderate            1
# 2  INS-W_1003_2021_13     Minimal         Minimal            1
# 3  INS-W_1004_2021_13     Minimal         Minimal            1
# 4  INS-W_1006_2021_13    Moderate        Moderate            1

# %% [markdown]
# ## 4. Compute metrics

# %%
metrics_vals = compute_metrics(results)
metrics = {
    "model_name":       model_name,
    "model_slug":       model_slug,
    "system_prompt_id": system_prompt_id,
    "system_prompt_text": system_prompt_text,
    "created_at":       datetime.now().isoformat(),
    **metrics_vals,
}

print(json.dumps(metrics, indent=2))
# Out:
# {
#   "model_name": "google/medgemma-4b-it",
#   "model_slug": "medgemma15",
#   "system_prompt_id": "you_are_a_clinical_decision_support_assistant_specializing_in_be",
#   "system_prompt_text": "You are a clinical decision support assistant specializing in behavioral health risk assessment. You will be given longitudinal behavioral data collected from mobile sensing (screen usage, sleep patterns, social proximity) for a patient, along with their Beck Depression Inventory (BDI) score at study enrollment. Your task is to predict the patient's depression severity category after the 8-week observation period. Respond with only one of the following labels: Minimal, Mild, Moderate, or Severe. Do not explain your reasoning.",
#   "created_at": "2026-04-10T02:29:43.252702",
#   "mode": "bdi",
#   "num_samples": 505,
#   "exact_match": 0.4574,
#   "normalized_match": 0.4574,
#   "parse_failure_rate": 0.0,
#   "recall_bdi_severe": 0.6296,
#   "recall_bdi_moderate": 0.9221,
#   "recall_bdi_minimal": 0.215,
#   "recall_bdi_mild": 0.8191
# }

# %% [markdown]
# ## 5. Save results

# %%
results_dir = ROOT / config["results_dir"]
results_dir.mkdir(parents=True, exist_ok=True)

stem = f"globem_{model_slug}_{system_prompt_id}_{run_ts}"
predictions_path = results_dir / f"{stem}_predictions.csv"
metrics_path     = results_dir / f"{stem}_metrics.json"

results_df.to_csv(predictions_path, index=False)
with metrics_path.open("w", encoding="utf-8") as f:
    json.dump(metrics, f, indent=2, ensure_ascii=False)

print(f"Predictions → {predictions_path}")
print(f"Metrics     → {metrics_path}")
# Out:
# Predictions → /home/ubuntu/Baseline_Eval/results/globem_medgemma15_you_are_a_clinical_decision_support_assistant_specializing_in_be_20260410_022735_predictions.csv
# Metrics     → /home/ubuntu/Baseline_Eval/results/globem_medgemma15_you_are_a_clinical_decision_support_assistant_specializing_in_be_20260410_022735_metrics.json

# %%
import torch, gc

del pipe          # or whatever your pipeline variable is called
gc.collect()
torch.cuda.empty_cache()
